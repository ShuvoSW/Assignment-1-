# %% [markdown]
# <a href="https://colab.research.google.com/github/tajuar-akash-hub/Assignment-1-/blob/main/service_4_video_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2024-03-02 182146.png](data:image/png;base64,...)

# %% [markdown]
# # basics
# what is variable
#
# ---
# expand for more
#
#
#
# variable assignemnt
# variable types
# upper and lowercase
# letter (A-Z, a-z) digits(0-9)
# and the underscore character (_)
# can not start with a digit

# %%
var = 23.5
print(var)

var = "now i'm a string"
print(var)
# Out:
# 23.5
# now i'm a string

# %% [markdown]
# # List
# List is a data structure
# value access by index
# list initiate  = list=[1,2,3,4]
# in the code sectin we'll see how to access list values

# %% [markdown]
# **list slicing**
# add to note :what is list slicing?

# %%
list = [0,1,2,3,4,5]
print(list[0])
print(list[0:])  # to print all list
print(list[1])
print(list[:])  # also to print all list
print(list[2])
print(list[2:4])   #output : [2, 3]
print(list[3])
print(list[1:3]) #[1, 2] ques: why 1 ghor ag porjonto print hoy? kintu surur somoy thik e exact number theke start hoy?
print(list[4])
print(list[:4]) #output : [0, 1, 2, 3]
print(list[5])
# Out:
# 0
# [0, 1, 2, 3, 4, 5]
# 1
# [0, 1, 2, 3, 4, 5]
# 2
# [2, 3]
# 3
# [1, 2]
# 4
# [0, 1, 2, 3]

# %% [markdown]
# **negative index of list:**
# list = ['p', 'r', 'o', 'v', 'e']
#          -5 , -4 , -3 ,-2,-1
#
# starts from backward, start with back index
# so always starts with -1,
# which is e, so -1 to left jototuke jawya jay

# %%
list = ['p','r','o','v','e']
print(list[-5])
print(list[-4])
print(list[0])
# Out:
# p
# r
# p

# %% [markdown]
# # slice notation ,
# slice notation is used to extract a substring
# for example,

# %%
word = ['f','u','d','g','e']
print(word[0:2])
print(word[2:5])
print(word[:4])
print(word[:])
print(word[1:-1])
# Out:
# ['f', 'u']
# ['d', 'g', 'e']
# ['f', 'u', 'd', 'g']
# ['f', 'u', 'd', 'g', 'e']
# ['u', 'd', 'g']

# %% [markdown]
# # **list slicing **
#
# vejal : print(a[0:6:2])   # 2 means step size, explain it again , kintu 1 ghor kom keno 2 ,
# ques : shesher 2 ki 1 ghor kom hocche? tahole ekoi jaygay -ve number dile ki 1 ghor kombe?
# q2: print(a[::-2])  #explain it? keno
# video explanation : print(a[0:6:2]) , 2 ghor agaya jabo means, 2 number ghore giye thambo, jemon
# **[9,8,7,6,5,4] er 9 print korar pore 2 number ghor 7**
# explain it again : print(a[::-1]) #use chatgpt

# %%
a= [9,8,7,6,5,4]
print(a[0:3])

print(a[:4]) #default stop value will be n-1 : so prints 1 to 5

print(a[1:])

print(a[:])

print(a[2:2])  #vejal , bistarito explain koro

print(a[0:6:2])   # 2 means step size, explain it again , kintu 1 ghor kom keno 2 ?

print(a[::-2])  #explain it?[4, 6, 8]

print(a[::-1]) #retunn reverse of given list values
# Out:
# [9, 8, 7]
# [9, 8, 7, 6]
# [8, 7, 6, 5, 4]
# [9, 8, 7, 6, 5, 4]
# []
# [9, 7, 5]
# [4, 6, 8]
# [4, 5, 6, 7, 8, 9]

# %% [markdown]
# # python program to extend a list using append()

# %%
a= [10,12,13,17]
#appeding
a.append(20)
a.append(22)
print(a)
# Out:
# [10, 12, 13, 17, 20, 22]

# %% [markdown]
# # python program to extend a list

# %%
a= [10,12,13,17]
print(a)
a=a+[20] #extending array , appending a single value
print(a)
# Out:
# [10, 12, 13, 17]
# [10, 12, 13, 17, 20]

# %% [markdown]
# # append more than one value

# %%
a= [10,12,13,17]
a= a+[30,40]
print(a)
# Out:
# [10, 12, 13, 17, 30, 40]

# %% [markdown]
# # python program to appending a list using slicing

# %%
a= [10,12,13,17]

#add 1 number
a[:0] = [30]
print(a)
print(a[0:0])

#but problem, last time dekhlam  print(a[2:2]) empty string output dey keno?

#add two number
a[:0] = [40,50] #explain again , clear na
print(a)
# Out:
# [30, 10, 12, 13, 17]
# []
# [40, 50, 30, 10, 12, 13, 17]

# %% [markdown]
# # functions in python for list ,
# * append()
# * clear()
# * copy()   #returns a copy of the list
# * count()
# * extend() #add the element of a list(or any iterable) to the end of the currnet list
# * index()
# * insert()
# * pop()
# * remove()
# * reverse()
# * sort()

# %%
a= [10,20,30,5]
a.append(50)
print(a)
#print(a.sort(a)) #why it is not sorting ?
# Out:
# [10, 20, 30, 5, 50]

# %% [markdown]
# # Data structure
# **Strack**
# explained : what is strack, how stack works(lifo) ,
# stack item add : push operation
# stack item remove : pop operation
# ![image.png](
#
# )
#
# python list ke stack keno bolche?
# list bollei e hoto?
# stack bole ki alada kichu ache?

# %%
stack = []

#append() function to push
#element in the stack
stack.append('a')
stack.append('b')
stack.append('c')


print('inital stack')
print(stack)

#pop() function to pop
#elemnt from stack in LIFO ORDER
print('popping stack')
print(stack.pop()) #konta pop koreche eta return korche function ta?
print(stack.pop())
print(stack.pop())

print("printing final stack",stack)
# Out:
# inital stack
# ['a', 'b', 'c']
# popping stack
# c
# b
# a
# printing final stack []

# %% [markdown]
# # Queue
# quueu is a idea
# insertion and deletion happens on different ends (
# )
#
# insetion : push
# deletion : pop
# queue vide starts :35:00
#
# convention :
# insert kora : enqueue
# lat er ta  :rear
# first er ta  : front
# queue theke ber kora : dequeue
# details : check queue image in folder
#
# ques : real life software implementation e stack e example ki hote pare? plate er stack chara , computer er kajer khetre rahat vhai je stack er example diyechilo seta kivhabe kaj kore?

# %%
#initializing a queue

queue = []

#adding element to the queue

queue.append('a')
queue.append('b')
queue.append('c')

print("printing initial queue",queue)

#removing elements from the queue
print("/nElements dequeued from the queue")
print(queue.pop(0)) #only difference is index 0 , pop korbo
print(queue.pop(0))
print(queue.pop(0))

print("\n queue after removing elements")
print(queue)

#uncommenting print(queue.pop(0))
#will raise and indexError
#as as the queue is now empty
# Out:
# printing initial queue ['a', 'b', 'c']
# /nElements dequeued from the queue
# a
# b
# c
#
#  queue after removing elements
# []

# %% [markdown]
# # Tuples (Data structures)
# #difference between tuples and list
# tuples -
# 1)Syntax - items are surrounded in parenthesis , parentheis ()
# 2)Mutatbility :  tuples are immutable in nature
# 3) method : there are 33 availabe method on tuples
# 4) usability : in dictionary , we can use key using tuples
#
# LISTS:
# 1)Syntax -  items are surrounded in square bracket []
# 2)Mutatbility :  tuples are mutable in nature
# 3) method : there are 46 availabe method on tuples
# 4) usability : in dictionary , we can't use list as a key
#
#
#
#
# * tuple also has negative index and sicing
#
# tuple method here
#
#
# 1.   count()
# 2.   index()
# 3.   len()
# 4.   min()
# 5.   max()
# 6.   sum()
# 7.   sort()
# 8.   loop tuple

# %%
tuple = (0,1,2,3,4,5)
print(tuple[0])
print(tuple[0:])

print(tuple[1])
print(tuple[:])

print(tuple[2])
print(tuple[2:4])

print(tuple[3])
print(tuple[1:3])

print(tuple[4])
print(tuple[:4])

print(tuple[5])

#method in tuple
# Out:
# 0
# (0, 1, 2, 3, 4, 5)
# 1
# (0, 1, 2, 3, 4, 5)
# 2
# (2, 3)
# 3
# (1, 2)
# 4
# (0, 1, 2, 3)
# 5

# %% [markdown]
# # SETS(data strcures) (check image)
# unordered : print kora same order e print nao hote pare
# unchangeable : set are immutable , we can't modify items
# heterogeneous : set can contain data all of all types
# unque : set doesn't allow duplicate items (list and tuple allow kore)
#
# set operatins :
# 1) Union
# 2)intersection
# 3) difference
# 4) symmetric difference

# %%
# S = {20,'JESIA',35.75}
list = [20,'JESIA',35.75,20]
print("printing the list",list)
S = {20,'JESIA',35.75,20} #duplicate item print hobena
print(S)
# Out:
# printing the list [20, 'JESIA', 35.75, 20]
# {35.75, 20, 'JESIA'}

# %%
# Out:
# 2
# 2
